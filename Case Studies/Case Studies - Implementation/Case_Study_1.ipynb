# %%
import pandas as pd

# %%
df = pd.read_csv('Case_Study_1.csv')

# %%
df.head()
# Out:
#              Timestamp  Enter your Roll No. (eg. 31401)   Gender  \
# 0  31/01/2023 14:54:12                             31484  Female
# 1  01/02/2023 09:39:47                             31418    Male
# 2  01/02/2023 09:41:38                             31471    Male
# 3  01/02/2023 09:42:11                             31450    Male
# 4  01/02/2023 09:44:32                             31480  Female
#
#    Enter your FE aggregate CGPA: (eg. 9.90)  \
# 0                                      9.95
# 1                                     10.00
# 2                                      8.20
# 3                                      9.78
# 4                                     10.00
#
#    Enter your SE aggregate  CGPA: (eg. 8.20)  Sem 3 CGPA (eg. 9.60)  \
# 0                                       9.73                   9.40
# 1                                       8.84                   9.91
# 2                                       7.86                   9.02
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Timestamp, Enter your Roll No. (eg. 31401) , Gender, Enter your FE aggregate CGPA: (eg. 9.90), Enter your SE aggregate  CGPA: (eg. 8.20), Sem 3 CGPA (eg. 9.60), Discrete Mathematics (eg. C),   Eng. Mathematics III  , Data Structures and Algorithms  , Software Engineering  , Microprocessor  , Principles of Programming Languages   , Data Structures and Algorithms Lab   , Microprocessor Lab, Code of Conduct  , Project Based Learning  , Audit Course 4 (Water Management, Intellectual Rights & Patents, etc), Fundamentals of Data Structures  , Object Oriented Programming  , Computer Graphics   , Digital Electronics and Logic Design   , Humanity and Social Science   , Data Structures Lab  , OOP and Computer Graphics Lab  , Digital Electronics Lab  , Business Communication Skills Lab   , Audit Course 3 (eg. Foreign Language), Engineering Mathematics 3 Lab, Unnamed: 28, Unnamed: 29, Unnamed: 30, Unnamed: 31, Microprocessor Lab  ]
# Index: []
#
# ...

# %%
df_filled = df.fillna(method='ffill', axis=1)

# %%
print(df_filled)
# Out:
#               Timestamp Enter your Roll No. (eg. 31401)   Gender  \
# 0   31/01/2023 14:54:12                            31484  Female
# 1   01/02/2023 09:39:47                            31418    Male
# 2   01/02/2023 09:41:38                            31471    Male
# 3   01/02/2023 09:42:11                            31450    Male
# 4   01/02/2023 09:44:32                            31480  Female
# 5   01/02/2023 09:44:53                            31479  Female
# 6   01/02/2023 09:45:13                            31401    Male
# 7   01/02/2023 09:45:21                            31448    Male
# 8   01/02/2023 09:48:13                            31436    Male
# 9   01/02/2023 09:49:38                            31433    Male
# 10  01/02/2023 09:53:00                            31475    Male
# 11  01/02/2023 09:53:33                            31474    Male
# 12  01/02/2023 09:55:21                            31420    Male
# ...

# %%
df_filled.head()
# Out:
#              Timestamp Enter your Roll No. (eg. 31401)   Gender  \
# 0  31/01/2023 14:54:12                            31484  Female
# 1  01/02/2023 09:39:47                            31418    Male
# 2  01/02/2023 09:41:38                            31471    Male
# 3  01/02/2023 09:42:11                            31450    Male
# 4  01/02/2023 09:44:32                            31480  Female
#
#   Enter your FE aggregate CGPA: (eg. 9.90)  \
# 0                                     9.95
# 1                                     10.0
# 2                                      8.2
# 3                                     9.78
# 4                                     10.0
#
#   Enter your SE aggregate  CGPA: (eg. 8.20) Sem 3 CGPA (eg. 9.60)  \
# 0                                      9.73                   9.4
# 1                                      8.84                  9.91
# 2                                      7.86                  9.02
# ...

# %%
df_filled
# Out:
#               Timestamp Enter your Roll No. (eg. 31401)   Gender  \
# 0   31/01/2023 14:54:12                            31484  Female
# 1   01/02/2023 09:39:47                            31418    Male
# 2   01/02/2023 09:41:38                            31471    Male
# 3   01/02/2023 09:42:11                            31450    Male
# 4   01/02/2023 09:44:32                            31480  Female
# 5   01/02/2023 09:44:53                            31479  Female
# 6   01/02/2023 09:45:13                            31401    Male
# 7   01/02/2023 09:45:21                            31448    Male
# 8   01/02/2023 09:48:13                            31436    Male
# 9   01/02/2023 09:49:38                            31433    Male
# 10  01/02/2023 09:53:00                            31475    Male
# 11  01/02/2023 09:53:33                            31474    Male
# 12  01/02/2023 09:55:21                            31420    Male
# ...
